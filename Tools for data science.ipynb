# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Piriyapong W**\
# Project Manager

# %% [markdown]
# *I am interested in data science because 1) one of the most effective decision making approaches is based on data and 2) many successful businesses are data driven organizations*

# %% [markdown]
# ### The code is to convert from Celsius to Fahrenheit

# %%
celsius = float(input("Enter temp in celsius: "))
fahrenheit = (celsius * 9/5) + 32
print('%.2f Celsius is: %0.2f Fahrenheit' %(celsius, fahrenheit))
# Out:
# Enter temp in celsius:  70
# 70.00 Celsius is: 158.00 Fahrenheit

# %% [markdown]
# ### **Table**

# %% [markdown]
# | Car Type      | Price         |   Color    |
# | ------------- |:-------------:|:----------:|
# | Sedan         | 20k USD       |Red         |
# | SUV           | 25k USD       |Blue        |

# %% [markdown]
# ### **Horizontal**

# %% [markdown]
# USA
#
# ---
#
# Maxico
#
# ---
#
# Canada
#
# ---

# %% [markdown]
# ### **Bulleted points**

# %% [markdown]
# - topic 1
# + topic 2
